# %%
import os
import matplotlib.pyplot as plt
import pathlib
import tensorflow as tf
from tensorflow.keras import layers, models
from PIL import Image


# Mount Google Drive to access the dataset.
from google.colab import drive
drive.mount('/content/drive')

# -- function for cleaning or removing unsupported image ---
def clean_dataset(directory):
    print("🔍 Cleaning dataset...")
    for root, dirs, files in os.walk(directory):\

        for file in files:
            filepath = os.path.join(root, file)
            try:
                with Image.open(filepath) as img:
                    img.verify()  # Verify image is not corrupted
                    if img.format not in ['JPEG', 'PNG', 'BMP', 'GIF']:
                        raise ValueError(f"Unsupported format: {img.format}")
            except Exception as e:
                print(f"❌ Deleting invalid image: {filepath} ({e})")
                os.remove(filepath)
    print("✅ Dataset cleaning complete.")

# --- Create Custom ResNet Model ---
def create_custom_resnet_model(input_shape=(224, 224, 3), num_classes=2):
    inputs = layers.Input(shape=input_shape)

    # Initial Conv Layer
    x = layers.Conv2D(64, (7, 7), padding='same', strides=(2, 2))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)

    # ResNet Block
    def resnet_block(x, filters, stride=1):
        shortcut = x
        if stride != 1 or filters * 4 != x.shape[-1]:
            shortcut = layers.Conv2D(filters * 4, (1, 1), strides=stride, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)
        x = layers.Conv2D(filters, (1, 1), strides=stride, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters, (3, 3), padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(filters * 4, (1, 1), padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.add([x, shortcut])
        x = layers.Activation('relu')(x)
        return x

    # Residual blocks
    for _ in range(2):
        x = resnet_block(x, 64)
    for _ in range(2):
        x = resnet_block(x, 128, stride=2)
    for _ in range(2):
        x = resnet_block(x, 256, stride=2)
    for _ in range(2):
        x = resnet_block(x, 512, stride=2)

    # Final layers
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs=inputs, outputs=outputs)
    return model

# --- Define Dataset Path and Clean it ---
data_dir = ('/content/drive/MyDrive/Project/DATA SET')
clean_dataset(data_dir)
base_path = '/content/drive/MyDrive/Project'
save_dir = f'{base_path}/saved'
os.makedirs(save_dir, exist_ok=True)
# Out:
# Mounted at /content/drive
# 🔍 Cleaning dataset...
# ✅ Dataset cleaning complete.

# %%
# ---  Load Data ---

image_size = (224, 224)
batch_size = 16

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical',
    shuffle=True
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical',
    shuffle=False
)

class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Class names: {class_names}")
print(f"Number of classes: {num_classes}")

# ---  Compile and Train Model ---
model = create_custom_resnet_model(num_classes=num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Train the model
epochs = 15
try:
    history = model.fit(train_ds, validation_data=val_ds, epochs=epochs)
except Exception as e:
    print("❌ Error during training:", e)
# Out:
# Found 1320 files belonging to 2 classes.
# Using 1056 files for training.
# Found 1320 files belonging to 2 classes.
# Using 264 files for validation.
# Class names: ['CANCER', 'NON CANCER']
# Number of classes: 2
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      9,472 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 112, 112,  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 55, 55,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 55, 55,    │      4,160 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 55, 55,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 55, 55,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 55, 55,    │     36,928 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 55, 55,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 55, 55,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 55, 55,    │     16,640 │ activation_2[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 55, 55,    │     16,640 │ max_pooling2d[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 55, 55,    │      1,024 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 55, 55,    │      1,024 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 55, 55,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 55, 55,    │          0 │ add[0][0]         │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 55, 55,    │     16,448 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 55, 55,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 55, 55,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 55, 55,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 55, 55,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 55, 55,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 55, 55,    │     16,640 │ activation_5[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 55, 55,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 55, 55,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 55, 55,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │     32,896 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    147,584 │ activation_7[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │     66,048 │ activation_8[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │    131,584 │ activation_6[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      2,048 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 28, 28,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 14, 14,    │     65,664 │ activation_9[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 14, 14,    │    147,584 │ activation_10[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 14, 14,    │     66,048 │ activation_11[0]… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 14, 14,    │    262,656 │ activation_9[0][… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,048 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,048 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 7, 7, 256) │    131,328 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 256) │      1,024 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 7, 7, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 7, 7, 256) │    590,080 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 256) │      1,024 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 7, 7,      │    263,168 │ activation_14[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 7, 7,      │    525,312 │ activation_12[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      4,096 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      4,096 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 7, 7,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7,      │          0 │ add_4[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 4, 4, 256) │    262,400 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 4, 4, 256) │    590,080 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 256) │      1,024 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 4, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 4, 4,      │    263,168 │ activation_17[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 4, 4,      │  1,049,600 │ activation_15[0]… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      4,096 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4,      │      4,096 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 4, 4,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 4, 4,      │          0 │ add_5[0][0]       │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 2, 2, 512) │    524,800 │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 2, 2, 512) │  2,359,808 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 512) │      2,048 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 2, 2, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 2, 2,      │  1,050,624 │ activation_20[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 2, 2,      │  2,099,200 │ activation_18[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2,      │      8,192 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2,      │      8,192 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 2, 2,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 2, 2,      │          0 │ add_6[0][0]       │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 1, 1, 512) │  1,049,088 │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 1, 1, 512) │  2,359,808 │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1, 512) │      2,048 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 1, 1, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 1, 1,      │  1,050,624 │ activation_23[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 1, 1,      │  4,196,352 │ activation_21[0]… │
# │                     │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1,      │      8,192 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 1, 1,      │      8,192 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 1, 1,      │          0 │ batch_normalizat… │
# │                     │ 2048)             │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 1, 1,      │          0 │ add_7[0][0]       │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ activation_24[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │  1,049,088 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2)         │      1,026 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,565,506 (78.45 MB)
#  Trainable params: 20,527,490 (78.31 MB)
#  Non-trainable params: 38,016 (148.50 KB)
# Epoch 1/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 57s 194ms/step - accuracy: 0.6007 - loss: 1.6893 - val_accuracy: 0.7917 - val_loss: 0.3833
# Epoch 2/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 92ms/step - accuracy: 0.7360 - loss: 0.6085 - val_accuracy: 0.0417 - val_loss: 1.2372
# Epoch 3/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 97ms/step - accuracy: 0.8706 - loss: 0.3306 - val_accuracy: 0.3106 - val_loss: 1.0644
# Epoch 4/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 9s 82ms/step - accuracy: 0.9131 - loss: 0.2427 - val_accuracy: 0.8447 - val_loss: 0.4007
# Epoch 5/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.9401 - loss: 0.1732 - val_accuracy: 0.9053 - val_loss: 0.2715
# Epoch 6/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.9164 - loss: 0.2006 - val_accuracy: 0.5871 - val_loss: 1.9470
# Epoch 7/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9150 - loss: 0.2179 - val_accuracy: 0.9735 - val_loss: 0.0881
# Epoch 8/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 92ms/step - accuracy: 0.9653 - loss: 0.1125 - val_accuracy: 0.9697 - val_loss: 0.1486
# Epoch 9/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.9534 - loss: 0.1250 - val_accuracy: 0.9848 - val_loss: 0.0762
# Epoch 10/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.9619 - loss: 0.1098 - val_accuracy: 0.7992 - val_loss: 0.6566
# Epoch 11/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 11s 93ms/step - accuracy: 0.9641 - loss: 0.0982 - val_accuracy: 0.9432 - val_loss: 0.1969
# Epoch 12/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.9927 - loss: 0.0301 - val_accuracy: 0.9773 - val_loss: 0.0874
# Epoch 13/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.9342 - loss: 0.1598 - val_accuracy: 0.9659 - val_loss: 0.1092
# Epoch 14/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.9852 - loss: 0.0502 - val_accuracy: 0.9242 - val_loss: 0.2398
# Epoch 15/15
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.9675 - loss: 0.0902 - val_accuracy: 0.7045 - val_loss: 0.8170

# %%
#save model
model.save(f'{save_dir}/res_model3.h5')
print(f"model saved successfully to :{save_dir}/res_model3.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model saved successfully to :/content/drive/MyDrive/Project/saved/res_model3.h5

# %%
# Retrieve training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs_range = range(len(acc))

# Plot Accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss', marker='o')
plt.plot(epochs_range, val_loss, label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
image_path='/content/drive/MyDrive/Project/DATA SET/CANCER/CANCER_73.jpg'
img= cv2.imread(image_path)
plt.imshow(img)
plt.title("TEST IMAGE")
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import numpy as np
# Load and preprocess the image
img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Create a batch

# Normalize the image (important for consistent inference)
#img_array = img_array / 255.0

# Make a prediction using your trained model
predictions = model.predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
# Get the predicted class index
predicted_class_index = np.argmax(predictions)

# Use your class_names to get the predicted class name
predicted_class_name = class_names[predicted_class_index]

# Print the prediction
print(f"The image is predicted as: {predicted_class_name}")

# Optional: Display the image
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# The image is predicted as: CANCER

# %%
os.listdir('/content/drive/MyDrive/Project/DATA SET/CANCER')
# Out:
# ['CANCER_22.jpg',
#  'CANCER_24.jpg',
#  'CANCER_26.jpg',
#  'CANCER_12.jpg',
#  'CANCER_15.jpg',
#  'CANCER_20.jpg',
#  'CANCER_6.jpg',
#  'CANCER_7.jpg',
#  'CANCER_11.jpg',
#  'CANCER_10.jpg',
#  'CANCER_0.jpg',
#  'CANCER_23.jpg',
#  'CANCER_19.jpg',
#  'CANCER_3.jpg',
#  'CANCER_8.jpg',
#  'CANCER_9.jpg',
#  'CANCER_2.jpg',
#  'CANCER_25.jpg',
#  'CANCER_18.jpg',
#  'CANCER_16.jpg',
#  'CANCER_14.jpg',
#  'CANCER_1.jpg',
#  'CANCER_4.jpg',
#  'CANCER_28.jpg',
#  'CANCER_21.jpg',
#  'CANCER_17.jpg',
#  'CANCER_13.jpg',
#  'CANCER_5.jpg',
#  'CANCER_27.jpg',
#  'CANCER_94.jpg',
#  'CANCER_91.jpg',
#  'CANCER_42.jpg',
#  'CANCER_95.jpg',
#  'CANCER_72.jpg',
#  'CANCER_73.jpg',
#  'CANCER_55.jpg',
#  'CANCER_71.jpg',
#  'CANCER_54.jpg',
#  'CANCER_38.jpg',
#  'CANCER_45.jpg',
#  'CANCER_87.jpg',
#  'CANCER_90.jpg',
#  'CANCER_47.jpg',
#  'CANCER_70.jpg',
#  'CANCER_48.jpg',
#  'CANCER_58.jpg',
#  'CANCER_85.jpg',
#  'CANCER_50.jpg',
#  'CANCER_59.jpg',
#  'CANCER_43.jpg',
#  'CANCER_30.jpg',
#  'CANCER_60.jpg',
#  'CANCER_66.jpg',
#  'CANCER_96.jpg',
#  'CANCER_81.jpg',
#  'CANCER_34.jpg',
#  'CANCER_41.jpg',
#  'CANCER_77.jpg',
#  'CANCER_78.jpg',
#  'CANCER_84.jpg',
#  'CANCER_36.jpg',
#  'CANCER_62.jpg',
#  'CANCER_92.jpg',
#  'CANCER_67.jpg',
#  'CANCER_76.jpg',
#  'CANCER_46.jpg',
#  'CANCER_83.jpg',
#  'CANCER_64.jpg',
#  'CANCER_31.jpg',
#  'CANCER_61.jpg',
#  'CANCER_44.jpg',
#  'CANCER_49.jpg',
#  'CANCER_75.jpg',
#  'CANCER_82.jpg',
#  'CANCER_93.jpg',
#  'CANCER_68.jpg',
#  'CANCER_74.jpg',
#  'CANCER_65.jpg',
#  'CANCER_37.jpg',
#  'CANCER_32.jpg',
#  'CANCER_57.jpg',
#  'CANCER_80.jpg',
#  'CANCER_56.jpg',
#  'CANCER_63.jpg',
#  'CANCER_79.jpg',
#  'CANCER_89.jpg',
#  'CANCER_35.jpg',
#  'CANCER_39.jpg',
#  'CANCER_69.jpg',
#  'CANCER_52.jpg',
#  'CANCER_86.jpg',
#  'CANCER_88.jpg',
#  'CANCER_40.jpg',
#  'CANCER_53.jpg',
#  'CANCER_33.jpg',
#  'CANCER_51.jpg',
#  'CANCER_29.jpg',
#  'CANCER_98.jpg',
#  'CANCER_130.jpg',
#  'CANCER_101.jpg',
#  'CANCER_110.jpg',
#  'CANCER_112.jpg',
#  'CANCER_136.jpg',
#  'CANCER_134.jpg',
#  'CANCER_106.jpg',
#  'CANCER_131.jpg',
#  'CANCER_118.jpg',
#  'CANCER_104.jpg',
#  'CANCER_124.jpg',
#  'CANCER_135.jpg',
#  'CANCER_127.jpg',
#  'CANCER_128.jpg',
#  'CANCER_107.jpg',
#  'CANCER_102.jpg',
#  'CANCER_141.jpg',
#  'CANCER_138.jpg',
#  'CANCER_137.jpg',
#  'CANCER_133.jpg',
#  'CANCER_139.jpg',
#  'CANCER_97.jpg',
#  'CANCER_103.jpg',
#  'CANCER_116.jpg',
#  'CANCER_115.jpg',
#  'CANCER_113.jpg',
#  'CANCER_99.jpg',
#  'CANCER_105.jpg',
#  'CANCER_117.jpg',
#  'CANCER_109.jpg',
#  'CANCER_125.jpg',
#  'CANCER_120.jpg',
#  'CANCER_123.jpg',
#  'CANCER_119.jpg',
#  'CANCER_129.jpg',
#  'CANCER_114.jpg',
#  'CANCER_122.jpg',
#  'CANCER_140.jpg',
#  'CANCER_100.jpg',
#  'CANCER_126.jpg',
#  'CANCER_132.jpg',
#  'CANCER_121.jpg',
#  'CANCER_108.jpg',
#  'CANCER_111.jpg',
#  'CANCER_147.jpg',
#  'CANCER_152.jpg',
#  'CANCER_167.jpg',
#  'CANCER_160.jpg',
#  'CANCER_150.jpg',
#  'CANCER_166.jpg',
#  'CANCER_146.jpg',
#  'CANCER_148.jpg',
#  'CANCER_144.jpg',
#  'CANCER_164.jpg',
#  'CANCER_155.jpg',
#  'CANCER_143.jpg',
#  'CANCER_159.jpg',
#  'CANCER_162.jpg',
#  'CANCER_163.jpg',
#  'CANCER_145.jpg',
#  'CANCER_149.jpg',
#  'CANCER_157.jpg',
#  'CANCER_154.jpg',
#  'CANCER_158.jpg',
#  'CANCER_153.jpg',
#  'CANCER_142.jpg',
#  'CANCER_156.jpg',
#  'CANCER_151.jpg',
#  'CANCER_168.jpg',
#  'CANCER_165.jpg',
#  'CANCER_161.jpg',
#  'CANCER_185.jpg',
#  'CANCER_192.jpg',
#  'CANCER_216.jpg',
#  'CANCER_170.jpg',
#  'CANCER_171.jpg',
#  'CANCER_173.jpg',
#  'CANCER_174.jpg',
#  'CANCER_187.jpg',
#  'CANCER_180.jpg',
#  'CANCER_226.jpg',
#  'CANCER_215.jpg',
#  'CANCER_195.jpg',
#  'CANCER_201.jpg',
#  'CANCER_193.jpg',
#  'CANCER_191.jpg',
#  'CANCER_199.jpg',
#  'CANCER_175.jpg',
#  'CANCER_205.jpg',
#  'CANCER_210.jpg',
#  'CANCER_220.jpg',
#  'CANCER_200.jpg',
#  'CANCER_189.jpg',
#  'CANCER_176.jpg',
#  'CANCER_225.jpg',
#  'CANCER_204.jpg',
#  'CANCER_217.jpg',
#  'CANCER_194.jpg',
#  'CANCER_196.jpg',
#  'CANCER_172.jpg',
#  'CANCER_188.jpg',
#  'CANCER_213.jpg',
#  'CANCER_218.jpg',
#  'CANCER_178.jpg',
#  'CANCER_209.jpg',
#  'CANCER_212.jpg',
#  'CANCER_224.jpg',
#  'CANCER_182.jpg',
#  'CANCER_190.jpg',
#  'CANCER_223.jpg',
#  'CANCER_222.jpg',
#  'CANCER_202.jpg',
#  'CANCER_177.jpg',
#  'CANCER_197.jpg',
#  'CANCER_169.jpg',
#  'CANCER_198.jpg',
#  'CANCER_221.jpg',
#  'CANCER_181.jpg',
#  'CANCER_208.jpg',
#  'CANCER_186.jpg',
#  'CANCER_179.jpg',
#  'CANCER_206.jpg',
#  'CANCER_214.jpg',
#  'CANCER_211.jpg',
#  'CANCER_184.jpg',
#  'CANCER_203.jpg',
#  'CANCER_207.jpg',
#  'CANCER_183.jpg',
#  'CANCER_219.jpg',
#  'CANCER_263.jpg',
#  'CANCER_239.jpg',
#  'CANCER_249.jpg',
#  'CANCER_244.jpg',
#  'CANCER_260.jpg',
#  'CANCER_250.jpg',
#  'CANCER_228.jpg',
#  'CANCER_256.jpg',
#  'CANCER_254.jpg',
#  'CANCER_247.jpg',
#  'CANCER_232.jpg',
#  'CANCER_242.jpg',
#  'CANCER_259.jpg',
#  'CANCER_238.jpg',
#  'CANCER_258.jpg',
#  'CANCER_262.jpg',
#  'CANCER_243.jpg',
#  'CANCER_245.jpg',
#  'CANCER_255.jpg',
#  'CANCER_265.jpg',
#  'CANCER_240.jpg',
#  'CANCER_231.jpg',
#  'CANCER_251.jpg',
#  'CANCER_234.jpg',
#  'CANCER_236.jpg',
#  'CANCER_230.jpg',
#  'CANCER_235.jpg',
#  'CANCER_253.jpg',
#  'CANCER_267.jpg',
#  'CANCER_233.jpg',
#  'CANCER_227.jpg',
#  'CANCER_252.jpg',
#  'CANCER_246.jpg',
#  'CANCER_261.jpg',
#  'CANCER_248.jpg',
#  'CANCER_237.jpg',
#  'CANCER_241.jpg',
#  'CANCER_266.jpg',
#  'CANCER_264.jpg',
#  'CANCER_257.jpg',
#  'CANCER_229.jpg',
#  'CANCER_282.jpg',
#  'CANCER_308.jpg',
#  'CANCER_293.jpg',
#  'CANCER_323.jpg',
#  'CANCER_304.jpg',
#  'CANCER_313.jpg',
#  'CANCER_307.jpg',
#  'CANCER_271.jpg',
#  'CANCER_269.jpg',
#  'CANCER_318.jpg',
#  'CANCER_289.jpg',
#  'CANCER_310.jpg',
#  'CANCER_287.jpg',
#  'CANCER_290.jpg',
#  'CANCER_311.jpg',
#  'CANCER_315.jpg',
#  'CANCER_273.jpg',
#  'CANCER_286.jpg',
#  'CANCER_312.jpg',
#  'CANCER_278.jpg',
#  'CANCER_272.jpg',
#  'CANCER_275.jpg',
#  'CANCER_285.jpg',
#  'CANCER_283.jpg',
#  'CANCER_292.jpg',
#  'CANCER_299.jpg',
#  'CANCER_301.jpg',
#  'CANCER_321.jpg',
#  'CANCER_294.jpg',
#  'CANCER_297.jpg',
#  'CANCER_284.jpg',
#  'CANCER_277.jpg',
#  'CANCER_291.jpg',
#  'CANCER_300.jpg',
#  'CANCER_316.jpg',
#  'CANCER_288.jpg',
#  'CANCER_314.jpg',
#  'CANCER_280.jpg',
#  'CANCER_309.jpg',
#  'CANCER_270.jpg',
#  'CANCER_281.jpg',
#  'CANCER_305.jpg',
#  'CANCER_276.jpg',
#  'CANCER_322.jpg',
#  'CANCER_274.jpg',
#  'CANCER_319.jpg',
#  'CANCER_306.jpg',
#  'CANCER_317.jpg',
#  'CANCER_298.jpg',
#  'CANCER_302.jpg',
#  'CANCER_320.jpg',
#  'CANCER_279.jpg',
#  'CANCER_303.jpg',
#  'CANCER_268.jpg',
#  'CANCER_295.jpg',
#  'CANCER_296.jpg',
#  'CANCER_330.jpg',
#  'CANCER_368.jpg',
#  'CANCER_351.jpg',
#  'CANCER_362.jpg',
#  'CANCER_369.jpg',
#  'CANCER_365.jpg',
#  'CANCER_324.jpg',
#  'CANCER_356.jpg',
#  'CANCER_375.jpg',
#  'CANCER_344.jpg',
#  'CANCER_332.jpg',
#  'CANCER_341.jpg',
#  'CANCER_361.jpg',
#  'CANCER_378.jpg',
#  'CANCER_354.jpg',
#  'CANCER_363.jpg',
#  'CANCER_350.jpg',
#  'CANCER_364.jpg',
#  'CANCER_371.jpg',
#  'CANCER_379.jpg',
#  'CANCER_366.jpg',
#  'CANCER_340.jpg',
#  'CANCER_355.jpg',
#  'CANCER_360.jpg',
#  'CANCER_376.jpg',
#  'CANCER_333.jpg',
#  'CANCER_370.jpg',
#  'CANCER_337.jpg',
#  'CANCER_367.jpg',
#  'CANCER_335.jpg',
#  'CANCER_339.jpg',
#  'CANCER_342.jpg',
#  'CANCER_358.jpg',
#  'CANCER_326.jpg',
#  'CANCER_373.jpg',
#  'CANCER_372.jpg',
#  'CANCER_346.jpg',
#  'CANCER_374.jpg',
#  'CANCER_334.jpg',
#  'CANCER_352.jpg',
#  'CANCER_359.jpg',
#  'CANCER_357.jpg',
#  'CANCER_377.jpg',
#  'CANCER_347.jpg',
#  'CANCER_327.jpg',
#  'CANCER_328.jpg',
#  'CANCER_329.jpg',
#  'CANCER_353.jpg',
#  'CANCER_325.jpg',
#  'CANCER_349.jpg',
#  'CANCER_343.jpg',
#  'CANCER_331.jpg',
#  'CANCER_380.jpg',
#  'CANCER_348.jpg',
#  'CANCER_336.jpg',
#  'CANCER_338.jpg',
#  'CANCER_345.jpg',
#  'CANCER_427.jpg',
#  'CANCER_428.jpg',
#  'CANCER_421.jpg',
#  'CANCER_415.jpg',
#  'CANCER_405.jpg',
#  'CANCER_400.jpg',
#  'CANCER_431.jpg',
#  'CANCER_390.jpg',
#  'CANCER_407.jpg',
#  'CANCER_425.jpg',
#  'CANCER_418.jpg',
#  'CANCER_402.jpg',
#  'CANCER_420.jpg',
#  'CANCER_401.jpg',
#  'CANCER_412.jpg',
#  'CANCER_385.jpg',
#  'CANCER_387.jpg',
#  'CANCER_419.jpg',
#  'CANCER_417.jpg',
#  'CANCER_416.jpg',
#  'CANCER_410.jpg',
#  'CANCER_388.jpg',
#  'CANCER_391.jpg',
#  'CANCER_429.jpg',
#  'CANCER_408.jpg',
#  'CANCER_394.jpg',
#  'CANCER_397.jpg',
#  'CANCER_406.jpg',
#  'CANCER_423.jpg',
#  'CANCER_386.jpg',
#  'CANCER_404.jpg',
#  'CANCER_426.jpg',
#  'CANCER_382.jpg',
#  'CANCER_422.jpg',
#  'CANCER_383.jpg',
#  'CANCER_409.jpg',
#  'CANCER_392.jpg',
#  'CANCER_395.jpg',
#  'CANCER_384.jpg',
#  'CANCER_411.jpg',
#  'CANCER_413.jpg',
#  'CANCER_399.jpg',
#  'CANCER_396.jpg',
#  'CANCER_398.jpg',
#  'CANCER_389.jpg',
#  'CANCER_403.jpg',
#  'CANCER_424.jpg',
#  'CANCER_381.jpg',
#  'CANCER_414.jpg',
#  'CANCER_430.jpg',
#  'CANCER_393.jpg',
#  'CANCER_473.jpg',
#  'CANCER_470.jpg',
#  'CANCER_481.jpg',
#  'CANCER_478.jpg',
#  'CANCER_453.jpg',
#  'CANCER_474.jpg',
#  'CANCER_439.jpg',
#  'CANCER_488.jpg',
#  'CANCER_480.jpg',
#  'CANCER_465.jpg',
#  'CANCER_445.jpg',
#  'CANCER_444.jpg',
#  'CANCER_443.jpg',
#  'CANCER_485.jpg',
#  'CANCER_460.jpg',
#  'CANCER_452.jpg',
#  'CANCER_462.jpg',
#  'CANCER_436.jpg',
#  'CANCER_435.jpg',
#  'CANCER_484.jpg',
#  'CANCER_482.jpg',
#  'CANCER_440.jpg',
#  'CANCER_442.jpg',
#  'CANCER_489.jpg',
#  'CANCER_451.jpg',
#  'CANCER_483.jpg',
#  'CANCER_438.jpg',
#  'CANCER_459.jpg',
#  'CANCER_464.jpg',
#  'CANCER_491.jpg',
#  'CANCER_446.jpg',
#  'CANCER_454.jpg',
#  'CANCER_432.jpg',
#  'CANCER_469.jpg',
#  'CANCER_455.jpg',
#  'CANCER_486.jpg',
#  'CANCER_466.jpg',
#  'CANCER_477.jpg',
#  'CANCER_468.jpg',
#  'CANCER_457.jpg',
#  'CANCER_456.jpg',
#  'CANCER_476.jpg',
#  'CANCER_471.jpg',
#  'CANCER_490.jpg',
#  'CANCER_450.jpg',
#  'CANCER_448.jpg',
#  'CANCER_463.jpg',
#  'CANCER_479.jpg',
#  'CANCER_441.jpg',
#  'CANCER_461.jpg',
#  'CANCER_447.jpg',
#  'CANCER_472.jpg',
#  'CANCER_433.jpg',
#  'CANCER_437.jpg',
#  'CANCER_475.jpg',
#  'CANCER_467.jpg',
#  'CANCER_449.jpg',
#  'CANCER_487.jpg',
#  'CANCER_434.jpg',
#  'CANCER_458.jpg',
#  'CANCER_516.jpg',
#  'CANCER_525.jpg',
#  'CANCER_493.jpg',
#  'CANCER_540.jpg',
#  'CANCER_507.jpg',
#  'CANCER_517.jpg',
#  'CANCER_512.jpg',
#  'CANCER_521.jpg',
#  'CANCER_534.jpg',
#  'CANCER_539.jpg',
#  'CANCER_528.jpg',
#  'CANCER_504.jpg',
#  'CANCER_535.jpg',
#  'CANCER_520.jpg',
#  'CANCER_530.jpg',
#  'CANCER_527.jpg',
#  'CANCER_542.jpg',
#  'CANCER_538.jpg',
#  'CANCER_541.jpg',
#  'CANCER_529.jpg',
#  'CANCER_501.jpg',
#  'CANCER_518.jpg',
#  'CANCER_505.jpg',
#  'CANCER_523.jpg',
#  'CANCER_499.jpg',
#  'CANCER_532.jpg',
#  'CANCER_510.jpg',
#  'CANCER_498.jpg',
#  'CANCER_519.jpg',
#  'CANCER_492.jpg',
#  'CANCER_509.jpg',
#  'CANCER_496.jpg',
#  'CANCER_508.jpg',
#  'CANCER_533.jpg',
#  'CANCER_503.jpg',
#  'CANCER_522.jpg',
#  'CANCER_506.jpg',
#  'CANCER_511.jpg',
#  'CANCER_495.jpg',
#  'CANCER_536.jpg',
#  'CANCER_497.jpg',
#  'CANCER_515.jpg',
#  'CANCER_524.jpg',
#  'CANCER_537.jpg',
#  'CANCER_500.jpg',
#  'CANCER_531.jpg',
#  'CANCER_502.jpg',
#  'CANCER_513.jpg',
#  'CANCER_494.jpg',
#  'CANCER_514.jpg',
#  'CANCER_526.jpg',
#  'CANCER_552.jpg',
#  'CANCER_544.jpg',
#  'CANCER_573.jpg',
#  'CANCER_588.jpg',
#  'CANCER_574.jpg',
#  'CANCER_587.jpg',
#  'CANCER_564.jpg',
#  'CANCER_548.jpg',
#  'CANCER_546.jpg',
#  'CANCER_592.jpg',
#  'CANCER_566.jpg',
#  'CANCER_565.jpg',
#  'CANCER_569.jpg',
#  'CANCER_549.jpg',
#  'CANCER_555.jpg',
#  'CANCER_579.jpg',
#  'CANCER_547.jpg',
#  'CANCER_585.jpg',
#  'CANCER_582.jpg',
#  'CANCER_553.jpg',
#  'CANCER_586.jpg',
#  'CANCER_570.jpg',
#  'CANCER_567.jpg',
#  'CANCER_568.jpg',
#  'CANCER_597.jpg',
#  'CANCER_558.jpg',
#  'CANCER_545.jpg',
#  'CANCER_580.jpg',
#  'CANCER_584.jpg',
#  'CANCER_581.jpg',
#  'CANCER_563.jpg',
#  'CANCER_583.jpg',
#  'CANCER_593.jpg',
#  'CANCER_550.jpg',
#  'CANCER_572.jpg',
#  'CANCER_559.jpg',
#  'CANCER_571.jpg',
#  'CANCER_543.jpg',
#  'CANCER_591.jpg',
#  'CANCER_551.jpg',
#  'CANCER_577.jpg',
#  'CANCER_557.jpg',
#  'CANCER_556.jpg',
#  'CANCER_575.jpg',
#  'CANCER_576.jpg',
#  'CANCER_560.jpg',
#  'CANCER_590.jpg',
#  'CANCER_595.jpg',
#  'CANCER_596.jpg',
#  'CANCER_578.jpg',
#  'CANCER_594.jpg',
#  'CANCER_554.jpg',
#  'CANCER_561.jpg',
#  'CANCER_589.jpg',
#  'CANCER_562.jpg',
#  'CANCER_608.jpg',
#  'CANCER_601.jpg',
#  'CANCER_640.jpg',
#  'CANCER_623.jpg',
#  'CANCER_619.jpg',
#  'CANCER_632.jpg',
#  'CANCER_618.jpg',
#  'CANCER_610.jpg',
#  'CANCER_648.jpg',
#  'CANCER_656.jpg',
#  'CANCER_609.jpg',
#  'CANCER_620.jpg',
#  'CANCER_653.jpg',
#  'CANCER_651.jpg',
#  'CANCER_615.jpg',
#  'CANCER_633.jpg',
#  'CANCER_638.jpg',
#  'CANCER_600.jpg',
#  'CANCER_652.jpg',
#  'CANCER_643.jpg',
#  'CANCER_617.jpg',
#  'CANCER_614.jpg',
#  'CANCER_639.jpg',
#  'CANCER_642.jpg',
#  'CANCER_627.jpg',
#  'CANCER_650.jpg',
#  'CANCER_607.jpg',
#  'CANCER_628.jpg',
#  'CANCER_645.jpg',
#  'CANCER_612.jpg',
#  'CANCER_613.jpg',
#  'CANCER_631.jpg',
#  'CANCER_654.jpg',
#  'CANCER_649.jpg',
#  'CANCER_626.jpg',
#  'CANCER_625.jpg',
#  'CANCER_658.jpg',
#  'CANCER_630.jpg',
#  'CANCER_624.jpg',
#  'CANCER_641.jpg',
#  'CANCER_647.jpg',
#  'CANCER_616.jpg',
#  'CANCER_659.jpg',
#  'CANCER_634.jpg',
#  'CANCER_605.jpg',
#  'CANCER_646.jpg',
#  'CANCER_644.jpg',
#  'CANCER_622.jpg',
#  'CANCER_621.jpg',
#  'CANCER_598.jpg',
#  'CANCER_606.jpg',
#  'CANCER_636.jpg',
#  'CANCER_637.jpg',
#  'CANCER_635.jpg',
#  'CANCER_603.jpg',
#  'CANCER_599.jpg',
#  'CANCER_602.jpg',
#  'CANCER_655.jpg',
#  'CANCER_611.jpg',
#  'CANCER_657.jpg',
#  'CANCER_629.jpg',
#  'CANCER_604.jpg']
